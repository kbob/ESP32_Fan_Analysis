# %% [markdown]
# # Exploring Fan Tach Measurement
#
# I would like to read the speed of a computer fan with high accuracy and low
# latency.  That seems like a problem that would have been thoroughly analyzed
# and solved, but I'm not finding existing solutions.
#
# ## Literature
#
# ## Test Setup
#
# I'm working with a micro controller and a 4-pin fan with PWM input and a tach
# output.
#
# The fan is a [Noctua A4x10 5V PWM](https://noctua.at/en/nf-a4x10-5v-pwm).
# Noctua have published [a white paper](https://www.noctua.at/pub/media/wysiwyg/Noctua_PWM_specifications_white_paper.pdf) about their PWM system.  They've
# also published [a brief description of the fan's
# controller IC](https://noctua.at/en/ne_fd1_pwm_ic).
#
# For our purposes, the things to note are that the fan's nominal speed ranges
# from 1,000 to 5,000 RPM, it accepts a PWM input at 25 KHz, and it produces a
# tach output, which has two pulses per fan resolution.
#
# The micro controller is an ESP32S3.  The 'S3 has typical PWM outputs, and it
# has an input capture peripheral.  The PWM runs at 25 KHz and has 10 bit resolution. The capture peripheral can timestamp edges of a digital input
# signal with the value of a free-running counter that increments at 80 MHz.

# %%
# Fan parameters
PWM_FREQ = 25_000
TACH_PULSES_PER_REV = 2
FAN_MAX_SPEED = 5000

# MCU parameters
CLK_FREQ = 80_000_000
PWM_BITS = 10
PWM_RESOLUTION = 2**PWM_BITS

# %% [markdown]
# ## Firmware
#
# I've written code for the MCU that runs one of four fixed scenarios and records
# every edge of both the output PWM signal and the returning PWM signal.  It
# creates a "log file" (actually just a recording of the serial output) that has
# a compressed log file.
#
# The log file records a single 32 bit number for each recorded edge.  The
# number is one bit identifying the channel,PWM or tach; one bit for direction, rising or falling; and 30 bits of timestamp.  The timestamp is just the value of the 80 MHz counter at the instant of the edge.  It wraps around every 13 seconds.

# %%
from collections import namedtuple
from enum import IntEnum
import numpy as np
import re


class Channel(IntEnum):
    PWM = 1
    TACH = 0

class Dir(IntEnum):
    RISING = 1
    FALLING = 0


class Signal(namedtuple('Signal', 'name, chan, dir, clk')):
    
    def rising_edges(self):
        print(f'{self.dir=}')
        print(f'{self.dir == Dir.RISING=}')
        print(f'{Dir.RISING=}')
        print(f'{1 == Dir.RISING=}')
        print(f'{np.any(self.dir == Dir.RISING)=}')
        return self.clk[self.dir == Dir.RISING]
    
    def falling_edges(self):
        return self.clk[self.dir == Dir.FALLING]


class Scenario:

    def __init__(self, file, start_sec = 0):
        self.filename = file
        self._read(file, start_clk=int(start_sec * CLK_FREQ))

    def _read(self, file, start_clk=0):
        contents = open(file).read()
        m = re.search(r'.* scenario', contents)
        assert m, f"can't find scenario description in {file}"
        self.description = m.group(0)
        m = re.search(r'(\d+) events logged', contents)
        assert m, f"can't find event count in {file}"
        self.edge_count = int(m.group(1))

        hex_data = contents[m.span()[1]:]
        hex_edges = re.findall(r'[\da-f]+', hex_data)
        assert len(hex_edges) == self.edge_count
        int_edges = [int(x, base=16) for x in hex_edges]
        self.raw_edges = np.array(int_edges, dtype=np.uint32)

        edges = self._unwrap(self.raw_edges)
        # N.B. edges are now (signed) int64.

        chan, dir, clk = self._decode(edges)

        offset = clk[0] - start_clk

        pwm_edges = edges[chan == 1]
        tach_edges = edges[chan == 0]
        self.pwm = Signal('pwm', *self._decode(pwm_edges, offset=offset))
        self.tach = Signal('tach', *self._decode(tach_edges, offset=offset))

    def _unwrap(self, edges):
        """Timestamps wrap around.  Convert to unwrapped."""
        # This function will preserve the flags in the low bits.
        # N.B., sometimes edges are out of order, so the data
        # may wrap backward as well as forward.
        edges = np.array(edges, dtype=np.int64)
        delta = edges[1:] - edges[:-1]
        overflow = delta < -2**31
        underflow = delta > +2**31
        eitherflow = overflow.astype(np.int64) - underflow.astype(np.int64)
        # adjustment = 2**32 * np.cumsum(eitherflow)
        adjustment = 2**32 * eitherflow.cumsum()
        adjustment = np.hstack([[0], adjustment])
        return edges + adjustment

        return edges

    def _decode(self, edges, offset=0):
        # Each edge is 32 bits and encodes
        #  - a channel (tach = 0, PWM = 1)
        #  - a direction (falling = 0, rising = 1)
        #  - a 30 bit timestamp
        chan = edges & 1
        dir = edges >> 1 & 1
        clk = ((edges >> 2) - offset) & 0x3FFF_FFFF
        return (chan, dir, clk)

    def __repr__(self):
        return f'<{self.__class__.__name__}: {self.description}>'

    def __len__(self):
        return self.edge_count;

# Quick unwrap test
edges = np.array([0xFFFFFFFE, 0, 1, 0xFFFFFFFF,
                  1, 2, 0x7FFFFFFF, 0xFFFF0000, 3], dtype=np.uint32)
unwrapped = Scenario._unwrap(None, edges)
assert list(unwrapped) == [0xFFFFFFFE, 0x100000000, 0x100000001, 0xFFFFFFFF,
                           0x100000001, 0x100000002, 0x17FFFFFFF, 0x1FFFF0000,
                           0x200000003]

# %% [markdown]
# ## Scenarios
#
# There are four scenarios.
#
#  * **Half Speed** -- The PWM signal is at a steady 50% duty cycle for
#  five seconds.
#
#  * **Bang Bang** -- The PWM signal starts at 0.  It jumps to 100%, stays there
#  for five seconds, then jumps back to 0 and waits five seconds for the fan
#  to stop.
#
#  * **RAMP** -- The PWM signal starts at 0.  It gradually ramps up to 100% over
#  five seconds, then it ramps back down to 0 over the next 5 seconds.
#
#  * **Staircase** -- The PWM signal starts at 0.  It increases to 100% in eight steps, waiting 1.6 seconds at each step for the fan speed to (almost) stabilize.  Then it steps back down to 0 at the same speed.

# %%
half_speed = Scenario('../half-speed.log')
bang_bang = Scenario('../bang-bang.log', 1.0)
ramp = Scenario('../ramp.log')
staircase = Scenario('../staircase.log')

# %% [markdown]
# ## Checking the Signals
#
# I can test that the signals have some expected properties.  And then I can
# fix them up.
#
# ### Alternating Edges
#
# Every signal should strictly alternate rising and falling edges.

# %%
def verify_alternating_edges(scenario):
    for sig in [scenario.pwm, scenario.tach]:
        dir = sig.dir
        if len(dir):
            try:
                assert np.all(dir[::2] == dir[0])
                assert np.all(dir[1::2] != dir[0])
            except AssertionError:
                d0 = int(dir[0])
                anomalies = (dir != (d0 + np.arange(len(dir))) % 2).nonzero()[0]
                print(f'{len(anomalies)=}')
                print(f'{anomalies=}')
                for i in anomalies:
                    neighbors = np.arange(max(0, i - 2), i + 2)
                    print(f'{scenario.description}: {sig.name}')
                    print(f'    at {i}')
                    print(f'    dir {dir[neighbors]}')
                    print(f'    clk {sig.clk[neighbors] - ([0] + sig.clk)[neighbors]}')
                raise

try:
    verify_alternating_edges(half_speed)
except AssertionError:
    for i in [568, 684]:
        half_speed.tach.dir[i] = 1
    verify_alternating_edges(half_speed)

verify_alternating_edges(bang_bang)

verify_alternating_edges(ramp)

#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477451
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477453
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477455
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477457
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477459
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477461
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477463
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477465
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477467
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477469
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477471
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477473
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477475
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477477
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477479
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477481
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477483
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477485
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477487
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477489
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477491
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477493
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477495
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477497
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477499
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477501
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477503
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477505
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477507
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477509
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477511
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477513
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477515
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477517
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477519
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477521
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477523
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477525
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477527
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477529
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477531
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477533
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477535
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477537
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477539
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477541
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477543
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477545
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477547
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477549
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477551
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477553
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477555
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477557
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477559
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477561
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477563
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477565
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477567
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477569
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477571
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477573
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477575
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477577
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477579
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477581
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477583
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477585
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477587
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477589
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477591
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477593
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477595
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477597
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477599
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477601
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477603
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477605
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477607
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477609
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477611
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477613
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477615
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477617
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477619
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477621
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477623
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477625
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477627
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477629
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477631
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477633
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477635
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477637
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477639
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477641
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477643
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477645
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477647
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477649
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477651
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477653
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477655
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477657
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477659
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477661
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477663
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477665
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477667
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477669
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477671
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477673
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477675
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477677
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477679
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477681
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477683
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477685
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477687
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477689
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477691
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477693
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477695
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477697
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477699
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477701
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477703
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477705
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477707
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477709
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477711
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477713
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477715
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477717
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477719
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477721
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477723
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477725
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477727
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477729
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477731
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477733
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477735
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477737
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477739
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477741
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477743
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477745
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477747
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477749
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477751
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477753
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477755
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477757
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477759
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477761
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477763
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477765
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477767
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477769
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477771
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477773
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477775
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477777
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477779
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477781
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477783
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477785
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477787
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477789
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477791
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477793
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477795
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477797
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477799
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477801
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477803
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477805
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477807
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477809
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477811
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477813
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477815
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477817
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477819
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477821
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477823
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477825
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477827
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477829
#     dir [0 0 0 0]
#     clk [0 0 0 0]
# Ramp scenario: pwm
#     at 477831
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[69], line 6, in verify_alternating_edges(scenario)
#       5 try:
# ----> 6     assert np.all(dir[::2] == dir[0])
#       7     assert np.all(dir[1::2] != dir[0])
#
# AssertionError:
#
# During handling of the above exception, another exception occurred:
#
# IndexError                                Traceback (most recent call last)
# Cell In[69], line 30
#      26     verify_alternating_edges(half_speed)
#      28 verify_alternating_edges(bang_bang)
# ---> 30 verify_alternating_edges(ramp)
#      32 try:
#      33     verify_alternating_edges(staircase)
#
# Cell In[69], line 17, in verify_alternating_edges(scenario)
#      15     print(f'{scenario.description}: {sig.name}')
#      16     print(f'    at {i}')
# ---> 17     print(f'    dir {dir[neighbors]}')
#      18     print(f'    clk {sig.clk[neighbors] - ([0] + sig.clk)[neighbors]}')
#      19 raise
#
# IndexError: index 477832 is out of bounds for axis 0 with size 477832

# %%
def verify_pwm_sync(scenario):
    print(f'\n{scenario.description}\n')
    pwm = scenario.pwm

    f_clk_per_pulse = CLK_FREQ / PWM_FREQ
    clk_per_pulse = int(f_clk_per_pulse)
    assert clk_per_pulse == f_clk_per_pulse
    # print(f'{clk_per_pulse=}')

    rising = pwm.rising_edges()
    # print(f'{len(rising)=}')
    print(f'{len(pwm.dir)=}')
    z = (rising - rising[0]) % clk_per_pulse != 0
    print(f'{rising[:4]=}')
    # print(f'{rising[z]=}')
    # print(f'{np.argwhere(z)=}')
    print(f'{rising[112714:112721]=}')
    print(f'{pwm.falling_edges()[112714:112721]=}')
    assert np.all((rising - rising[0]) % clk_per_pulse == 0)

try:
    verify_alternating_edges(half_speed)
except AssertionError:
    show_nonalternating_edges(half_speed)
# verify_pwm_sync(half_speed)
# verify_pwm_sync(bang_bang)
# verify_pwm_sync(ramp)
# verify_pwm_sync(staircase)
